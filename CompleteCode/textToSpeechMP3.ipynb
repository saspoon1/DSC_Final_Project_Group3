# %%
#Replace name with your unique bucket name, remember it for later in the next code block
insert_name = "neelmiranitest2"
bucketname = f"s3://{insert_name}"
# !aws s3 mb $bucketname
# Out:
# make_bucket: neelmiranitest2

# %%
# Check to see if bucket was made
# !aws s3 ls
# Out:
# 2022-10-17 14:52:32 ethanisstupidpt2
# 2022-10-31 14:13:23 hw3dscneelmirani
# 2022-10-24 14:43:45 image-api-example-neel-mirani
# 2022-10-31 01:43:43 license1neelmirani
# 2022-11-22 19:42:35 neelmiranitest1
# 2022-11-22 20:05:32 neelmiranitest2
# 2022-11-09 15:08:31 sagemaker-studio-625190418192-b5lgofd2pra
# 2022-11-09 15:13:57 sagemaker-us-east-1-625190418192
# 2022-11-05 21:04:37 speechfilesqtmg3

# %%
# import pandas lib as pd
import pandas as pd
 
# read by default 1st sheet of an excel file
df = pd.read_excel('/home/ec2-user/SageMaker/DSC_Final_Project_Group3/Data/100Random.xlsx')

print(df)
# Out:
#                                              Original
# 0   Gwen had her best sleep ever on her new bed of...
# 1   When confronted with a rotary dial phone the t...
# 2   There was no telling what thoughts would come ...
# 3          Baby wipes are made of chocolate stardust.
# 4   It caught him off guard that space smelled of ...
# ..                                                ...
# 95                            Love is not like pizza.
# 96           Her scream silenced the rowdy teenagers.
# 97  The waves were crashing on the shore, it was a...
# 98  Sometimes you have to just give up and win by ...
# 99       He loved eating his bananas in hot dog buns.
#
# [100 rows x 1 columns]

# %%
import boto3
from botocore.exceptions import BotoCoreError, ClientError
from contextlib import closing
import os
import sys
import subprocess
import io
from tempfile import gettempdir
# Create a client using the credentials and region defined in the [adminuser]
polly = boto3.client('polly', region_name='us-east-1')

# Create mp3 file for all sentences with each voice accent
voices = ["Joanna", "Emma", "Seoyeon", "Lea", "Lucia", "Aditi"]
for voice in voices:
    folder = f'/home/ec2-user/SageMaker/DSC_Final_Project_Group3/CompleteCode/{voice}' #change
    os.mkdir(folder)
    i = 0
    for sentence in df["Original"]:
        i += 1
        response = polly.synthesize_speech(Text= sentence, OutputFormat="mp3",
        VoiceId=f"{voice}", LanguageCode = "en-US")

        if "AudioStream" in response:
            with closing(response["AudioStream"]) as stream:
                output = os.path.join(f"/home/ec2-user/SageMaker/DSC_Final_Project_Group3/CompleteCode/{voice}", f"{voice + str(i)}.mp3") #change
                try:
         # Open a file for writing the output as a binary stream
                    with open(output, "wb") as file:
                        file.write(stream.read())
                except IOError as error:
         # Could not write to file, exit gracefully
                    print(error)
                    sys.exit(-1)
        else:
         # The response didn't contain audio data, exit gracefully
            print("Could not stream audio")
            sys.exit(-1)

# %%
# Move all mp3 files into S3 Bucket
import os
voices = ["Joanna", "Emma", "Seoyeon", "Lea", "Lucia", "Aditi"]
string = ""
for voice in voices:
    for name in os.listdir(f"/home/ec2-user/SageMaker/DSC_Final_Project_Group3/CompleteCode/{voice}"):
        string = f"/home/ec2-user/SageMaker/DSC_Final_Project_Group3/CompleteCode/{voice}/{name}"
        # !aws s3 mv $string $bucketname
# Out:
# move: Joanna/Joanna8.mp3 to s3://neelmiranitest2/Joanna8.mp3
# move: Joanna/Joanna31.mp3 to s3://neelmiranitest2/Joanna31.mp3
# move: Joanna/Joanna73.mp3 to s3://neelmiranitest2/Joanna73.mp3
# move: Joanna/Joanna57.mp3 to s3://neelmiranitest2/Joanna57.mp3
# move: Joanna/Joanna7.mp3 to s3://neelmiranitest2/Joanna7.mp3
# move: Joanna/Joanna59.mp3 to s3://neelmiranitest2/Joanna59.mp3
# move: Joanna/Joanna34.mp3 to s3://neelmiranitest2/Joanna34.mp3
# move: Joanna/Joanna82.mp3 to s3://neelmiranitest2/Joanna82.mp3
# move: Joanna/Joanna37.mp3 to s3://neelmiranitest2/Joanna37.mp3
# move: Joanna/Joanna52.mp3 to s3://neelmiranitest2/Joanna52.mp3
# move: Joanna/Joanna48.mp3 to s3://neelmiranitest2/Joanna48.mp3
# move: Joanna/Joanna9.mp3 to s3://neelmiranitest2/Joanna9.mp3
# move: Joanna/Joanna97.mp3 to s3://neelmiranitest2/Joanna97.mp3
# move: Joanna/Joanna58.mp3 to s3://neelmiranitest2/Joanna58.mp3
# move: Joanna/Joanna86.mp3 to s3://neelmiranitest2/Joanna86.mp3
# move: Joanna/Joanna93.mp3 to s3://neelmiranitest2/Joanna93.mp3
# move: Joanna/Joanna50.mp3 to s3://neelmiranitest2/Joanna50.mp3
# move: Joanna/Joanna63.mp3 to s3://neelmiranitest2/Joanna63.mp3
# move: Joanna/Joanna26.mp3 to s3://neelmiranitest2/Joanna26.mp3
# move: Joanna/Joanna60.mp3 to s3://neelmiranitest2/Joanna60.mp3
# move: Joanna/Joanna84.mp3 to s3://neelmiranitest2/Joanna84.mp3
# move: Joanna/Joanna75.mp3 to s3://neelmiranitest2/Joanna75.mp3
# move: Joanna/Joanna53.mp3 to s3://neelmiranitest2/Joanna53.mp3
# move: Joanna/Joanna67.mp3 to s3://neelmiranitest2/Joanna67.mp3
# move: Joanna/Joanna55.mp3 to s3://neelmiranitest2/Joanna55.mp3
# move: Joanna/Joanna77.mp3 to s3://neelmiranitest2/Joanna77.mp3
# move: Joanna/Joanna96.mp3 to s3://neelmiranitest2/Joanna96.mp3
# move: Joanna/Joanna62.mp3 to s3://neelmiranitest2/Joanna62.mp3
# move: Joanna/Joanna74.mp3 to s3://neelmiranitest2/Joanna74.mp3
# move: Joanna/Joanna6.mp3 to s3://neelmiranitest2/Joanna6.mp3
# move: Joanna/Joanna71.mp3 to s3://neelmiranitest2/Joanna71.mp3
# move: Joanna/Joanna87.mp3 to s3://neelmiranitest2/Joanna87.mp3
# move: Joanna/Joanna98.mp3 to s3://neelmiranitest2/Joanna98.mp3
# move: Joanna/Joanna45.mp3 to s3://neelmiranitest2/Joanna45.mp3
# move: Joanna/Joanna90.mp3 to s3://neelmiranitest2/Joanna90.mp3
# move: Joanna/Joanna14.mp3 to s3://neelmiranitest2/Joanna14.mp3
# move: Joanna/Joanna3.mp3 to s3://neelmiranitest2/Joanna3.mp3
# move: Joanna/Joanna28.mp3 to s3://neelmiranitest2/Joanna28.mp3
# move: Joanna/Joanna40.mp3 to s3://neelmiranitest2/Joanna40.mp3
# move: Joanna/Joanna1.mp3 to s3://neelmiranitest2/Joanna1.mp3
# move: Joanna/Joanna72.mp3 to s3://neelmiranitest2/Joanna72.mp3
# move: Joanna/Joanna35.mp3 to s3://neelmiranitest2/Joanna35.mp3
# move: Joanna/Joanna79.mp3 to s3://neelmiranitest2/Joanna79.mp3
# move: Joanna/Joanna85.mp3 to s3://neelmiranitest2/Joanna85.mp3
# move: Joanna/Joanna92.mp3 to s3://neelmiranitest2/Joanna92.mp3
# move: Joanna/Joanna56.mp3 to s3://neelmiranitest2/Joanna56.mp3
# move: Joanna/Joanna83.mp3 to s3://neelmiranitest2/Joanna83.mp3
# move: Joanna/Joanna51.mp3 to s3://neelmiranitest2/Joanna51.mp3
# move: Joanna/Joanna11.mp3 to s3://neelmiranitest2/Joanna11.mp3
# move: Joanna/Joanna94.mp3 to s3://neelmiranitest2/Joanna94.mp3
# move: Joanna/Joanna43.mp3 to s3://neelmiranitest2/Joanna43.mp3
# move: Joanna/Joanna16.mp3 to s3://neelmiranitest2/Joanna16.mp3
# move: Joanna/Joanna18.mp3 to s3://neelmiranitest2/Joanna18.mp3
# move: Joanna/Joanna81.mp3 to s3://neelmiranitest2/Joanna81.mp3
# move: Joanna/Joanna76.mp3 to s3://neelmiranitest2/Joanna76.mp3
# move: Joanna/Joanna2.mp3 to s3://neelmiranitest2/Joanna2.mp3
# move: Joanna/Joanna42.mp3 to s3://neelmiranitest2/Joanna42.mp3
# move: Joanna/Joanna21.mp3 to s3://neelmiranitest2/Joanna21.mp3
# move: Joanna/Joanna69.mp3 to s3://neelmiranitest2/Joanna69.mp3
# move: Joanna/Joanna23.mp3 to s3://neelmiranitest2/Joanna23.mp3
# move: Joanna/Joanna88.mp3 to s3://neelmiranitest2/Joanna88.mp3
# move: Joanna/Joanna44.mp3 to s3://neelmiranitest2/Joanna44.mp3
# move: Joanna/Joanna47.mp3 to s3://neelmiranitest2/Joanna47.mp3
# move: Joanna/Joanna89.mp3 to s3://neelmiranitest2/Joanna89.mp3
# move: Joanna/Joanna33.mp3 to s3://neelmiranitest2/Joanna33.mp3
# move: Joanna/Joanna22.mp3 to s3://neelmiranitest2/Joanna22.mp3
# move: Joanna/Joanna32.mp3 to s3://neelmiranitest2/Joanna32.mp3
# move: Joanna/Joanna27.mp3 to s3://neelmiranitest2/Joanna27.mp3
# move: Joanna/Joanna4.mp3 to s3://neelmiranitest2/Joanna4.mp3
# move: Joanna/Joanna36.mp3 to s3://neelmiranitest2/Joanna36.mp3
# move: Joanna/Joanna46.mp3 to s3://neelmiranitest2/Joanna46.mp3
# move: Joanna/Joanna39.mp3 to s3://neelmiranitest2/Joanna39.mp3
# move: Joanna/Joanna68.mp3 to s3://neelmiranitest2/Joanna68.mp3
# move: Joanna/Joanna100.mp3 to s3://neelmiranitest2/Joanna100.mp3
# move: Joanna/Joanna24.mp3 to s3://neelmiranitest2/Joanna24.mp3
# move: Joanna/Joanna54.mp3 to s3://neelmiranitest2/Joanna54.mp3
# move: Joanna/Joanna80.mp3 to s3://neelmiranitest2/Joanna80.mp3
# move: Joanna/Joanna65.mp3 to s3://neelmiranitest2/Joanna65.mp3
# move: Joanna/Joanna95.mp3 to s3://neelmiranitest2/Joanna95.mp3
# move: Joanna/Joanna12.mp3 to s3://neelmiranitest2/Joanna12.mp3
# move: Joanna/Joanna78.mp3 to s3://neelmiranitest2/Joanna78.mp3
# move: Joanna/Joanna91.mp3 to s3://neelmiranitest2/Joanna91.mp3
# move: Joanna/Joanna29.mp3 to s3://neelmiranitest2/Joanna29.mp3
# move: Joanna/Joanna10.mp3 to s3://neelmiranitest2/Joanna10.mp3
# move: Joanna/Joanna17.mp3 to s3://neelmiranitest2/Joanna17.mp3
# move: Joanna/Joanna38.mp3 to s3://neelmiranitest2/Joanna38.mp3
# move: Joanna/Joanna61.mp3 to s3://neelmiranitest2/Joanna61.mp3
# move: Joanna/Joanna13.mp3 to s3://neelmiranitest2/Joanna13.mp3
# move: Joanna/Joanna25.mp3 to s3://neelmiranitest2/Joanna25.mp3
# move: Joanna/Joanna99.mp3 to s3://neelmiranitest2/Joanna99.mp3
# move: Joanna/Joanna30.mp3 to s3://neelmiranitest2/Joanna30.mp3
# move: Joanna/Joanna20.mp3 to s3://neelmiranitest2/Joanna20.mp3
# move: Joanna/Joanna49.mp3 to s3://neelmiranitest2/Joanna49.mp3
# move: Joanna/Joanna41.mp3 to s3://neelmiranitest2/Joanna41.mp3
# move: Joanna/Joanna70.mp3 to s3://neelmiranitest2/Joanna70.mp3
# move: Joanna/Joanna64.mp3 to s3://neelmiranitest2/Joanna64.mp3
# move: Joanna/Joanna15.mp3 to s3://neelmiranitest2/Joanna15.mp3
# move: Joanna/Joanna5.mp3 to s3://neelmiranitest2/Joanna5.mp3
# move: Joanna/Joanna66.mp3 to s3://neelmiranitest2/Joanna66.mp3
# move: Joanna/Joanna19.mp3 to s3://neelmiranitest2/Joanna19.mp3
# move: Emma/Emma35.mp3 to s3://neelmiranitest2/Emma35.mp3
# move: Emma/Emma97.mp3 to s3://neelmiranitest2/Emma97.mp3
# move: Emma/Emma82.mp3 to s3://neelmiranitest2/Emma82.mp3
# move: Emma/Emma72.mp3 to s3://neelmiranitest2/Emma72.mp3
# move: Emma/Emma88.mp3 to s3://neelmiranitest2/Emma88.mp3
# move: Emma/Emma37.mp3 to s3://neelmiranitest2/Emma37.mp3
# move: Emma/Emma81.mp3 to s3://neelmiranitest2/Emma81.mp3
# move: Emma/Emma43.mp3 to s3://neelmiranitest2/Emma43.mp3
# move: Emma/Emma69.mp3 to s3://neelmiranitest2/Emma69.mp3
# move: Emma/Emma27.mp3 to s3://neelmiranitest2/Emma27.mp3
# move: Emma/Emma31.mp3 to s3://neelmiranitest2/Emma31.mp3
# move: Emma/Emma100.mp3 to s3://neelmiranitest2/Emma100.mp3
# move: Emma/Emma48.mp3 to s3://neelmiranitest2/Emma48.mp3
# move: Emma/Emma86.mp3 to s3://neelmiranitest2/Emma86.mp3
# move: Emma/Emma58.mp3 to s3://neelmiranitest2/Emma58.mp3
# move: Emma/Emma41.mp3 to s3://neelmiranitest2/Emma41.mp3
# move: Emma/Emma93.mp3 to s3://neelmiranitest2/Emma93.mp3
# move: Emma/Emma89.mp3 to s3://neelmiranitest2/Emma89.mp3
# move: Emma/Emma4.mp3 to s3://neelmiranitest2/Emma4.mp3
# move: Emma/Emma87.mp3 to s3://neelmiranitest2/Emma87.mp3
# move: Emma/Emma84.mp3 to s3://neelmiranitest2/Emma84.mp3
# move: Emma/Emma77.mp3 to s3://neelmiranitest2/Emma77.mp3
# move: Emma/Emma47.mp3 to s3://neelmiranitest2/Emma47.mp3
# move: Emma/Emma30.mp3 to s3://neelmiranitest2/Emma30.mp3
# move: Emma/Emma56.mp3 to s3://neelmiranitest2/Emma56.mp3
# move: Emma/Emma16.mp3 to s3://neelmiranitest2/Emma16.mp3
# move: Emma/Emma92.mp3 to s3://neelmiranitest2/Emma92.mp3
# move: Emma/Emma59.mp3 to s3://neelmiranitest2/Emma59.mp3
# move: Emma/Emma29.mp3 to s3://neelmiranitest2/Emma29.mp3
# move: Emma/Emma5.mp3 to s3://neelmiranitest2/Emma5.mp3
# move: Emma/Emma76.mp3 to s3://neelmiranitest2/Emma76.mp3
# move: Emma/Emma66.mp3 to s3://neelmiranitest2/Emma66.mp3
# move: Emma/Emma26.mp3 to s3://neelmiranitest2/Emma26.mp3
# move: Emma/Emma70.mp3 to s3://neelmiranitest2/Emma70.mp3
# move: Emma/Emma63.mp3 to s3://neelmiranitest2/Emma63.mp3
# move: Emma/Emma3.mp3 to s3://neelmiranitest2/Emma3.mp3
# move: Emma/Emma1.mp3 to s3://neelmiranitest2/Emma1.mp3
# move: Emma/Emma33.mp3 to s3://neelmiranitest2/Emma33.mp3
# move: Emma/Emma45.mp3 to s3://neelmiranitest2/Emma45.mp3
# move: Emma/Emma6.mp3 to s3://neelmiranitest2/Emma6.mp3
# move: Emma/Emma24.mp3 to s3://neelmiranitest2/Emma24.mp3
# move: Emma/Emma36.mp3 to s3://neelmiranitest2/Emma36.mp3
# move: Emma/Emma75.mp3 to s3://neelmiranitest2/Emma75.mp3
# move: Emma/Emma54.mp3 to s3://neelmiranitest2/Emma54.mp3
# move: Emma/Emma40.mp3 to s3://neelmiranitest2/Emma40.mp3
# move: Emma/Emma32.mp3 to s3://neelmiranitest2/Emma32.mp3
# move: Emma/Emma60.mp3 to s3://neelmiranitest2/Emma60.mp3
# move: Emma/Emma19.mp3 to s3://neelmiranitest2/Emma19.mp3
# move: Emma/Emma28.mp3 to s3://neelmiranitest2/Emma28.mp3
# move: Emma/Emma53.mp3 to s3://neelmiranitest2/Emma53.mp3
# move: Emma/Emma95.mp3 to s3://neelmiranitest2/Emma95.mp3
# move: Emma/Emma57.mp3 to s3://neelmiranitest2/Emma57.mp3
# move: Emma/Emma85.mp3 to s3://neelmiranitest2/Emma85.mp3
# move: Emma/Emma17.mp3 to s3://neelmiranitest2/Emma17.mp3
# move: Emma/Emma96.mp3 to s3://neelmiranitest2/Emma96.mp3
# move: Emma/Emma38.mp3 to s3://neelmiranitest2/Emma38.mp3
# move: Emma/Emma34.mp3 to s3://neelmiranitest2/Emma34.mp3
# move: Emma/Emma13.mp3 to s3://neelmiranitest2/Emma13.mp3
# move: Emma/Emma52.mp3 to s3://neelmiranitest2/Emma52.mp3
# move: Emma/Emma22.mp3 to s3://neelmiranitest2/Emma22.mp3
# move: Emma/Emma83.mp3 to s3://neelmiranitest2/Emma83.mp3
# move: Emma/Emma44.mp3 to s3://neelmiranitest2/Emma44.mp3
# move: Emma/Emma10.mp3 to s3://neelmiranitest2/Emma10.mp3
# move: Emma/Emma11.mp3 to s3://neelmiranitest2/Emma11.mp3
# move: Emma/Emma79.mp3 to s3://neelmiranitest2/Emma79.mp3
# move: Emma/Emma73.mp3 to s3://neelmiranitest2/Emma73.mp3
# move: Emma/Emma61.mp3 to s3://neelmiranitest2/Emma61.mp3
# move: Emma/Emma98.mp3 to s3://neelmiranitest2/Emma98.mp3
# move: Emma/Emma18.mp3 to s3://neelmiranitest2/Emma18.mp3
# move: Emma/Emma90.mp3 to s3://neelmiranitest2/Emma90.mp3
# move: Emma/Emma49.mp3 to s3://neelmiranitest2/Emma49.mp3
# move: Emma/Emma14.mp3 to s3://neelmiranitest2/Emma14.mp3
# move: Emma/Emma39.mp3 to s3://neelmiranitest2/Emma39.mp3
# move: Emma/Emma9.mp3 to s3://neelmiranitest2/Emma9.mp3
# move: Emma/Emma21.mp3 to s3://neelmiranitest2/Emma21.mp3
# move: Emma/Emma25.mp3 to s3://neelmiranitest2/Emma25.mp3
# move: Emma/Emma91.mp3 to s3://neelmiranitest2/Emma91.mp3
# move: Emma/Emma12.mp3 to s3://neelmiranitest2/Emma12.mp3
# move: Emma/Emma80.mp3 to s3://neelmiranitest2/Emma80.mp3
# move: Emma/Emma99.mp3 to s3://neelmiranitest2/Emma99.mp3
# move: Emma/Emma50.mp3 to s3://neelmiranitest2/Emma50.mp3
# move: Emma/Emma94.mp3 to s3://neelmiranitest2/Emma94.mp3
# move: Emma/Emma15.mp3 to s3://neelmiranitest2/Emma15.mp3
# move: Emma/Emma71.mp3 to s3://neelmiranitest2/Emma71.mp3
# move: Emma/Emma55.mp3 to s3://neelmiranitest2/Emma55.mp3
# move: Emma/Emma20.mp3 to s3://neelmiranitest2/Emma20.mp3
# move: Emma/Emma62.mp3 to s3://neelmiranitest2/Emma62.mp3
# move: Emma/Emma46.mp3 to s3://neelmiranitest2/Emma46.mp3
# move: Emma/Emma2.mp3 to s3://neelmiranitest2/Emma2.mp3
# move: Emma/Emma68.mp3 to s3://neelmiranitest2/Emma68.mp3
# move: Emma/Emma74.mp3 to s3://neelmiranitest2/Emma74.mp3
# move: Emma/Emma23.mp3 to s3://neelmiranitest2/Emma23.mp3
# move: Emma/Emma67.mp3 to s3://neelmiranitest2/Emma67.mp3
# move: Emma/Emma78.mp3 to s3://neelmiranitest2/Emma78.mp3
# move: Emma/Emma65.mp3 to s3://neelmiranitest2/Emma65.mp3
# move: Emma/Emma64.mp3 to s3://neelmiranitest2/Emma64.mp3
# move: Emma/Emma51.mp3 to s3://neelmiranitest2/Emma51.mp3
# move: Emma/Emma7.mp3 to s3://neelmiranitest2/Emma7.mp3
# move: Emma/Emma42.mp3 to s3://neelmiranitest2/Emma42.mp3
# move: Emma/Emma8.mp3 to s3://neelmiranitest2/Emma8.mp3
# move: Seoyeon/Seoyeon70.mp3 to s3://neelmiranitest2/Seoyeon70.mp3
# move: Seoyeon/Seoyeon39.mp3 to s3://neelmiranitest2/Seoyeon39.mp3
# move: Seoyeon/Seoyeon31.mp3 to s3://neelmiranitest2/Seoyeon31.mp3
# move: Seoyeon/Seoyeon94.mp3 to s3://neelmiranitest2/Seoyeon94.mp3
# move: Seoyeon/Seoyeon100.mp3 to s3://neelmiranitest2/Seoyeon100.mp3
# move: Seoyeon/Seoyeon38.mp3 to s3://neelmiranitest2/Seoyeon38.mp3
# move: Seoyeon/Seoyeon51.mp3 to s3://neelmiranitest2/Seoyeon51.mp3
# move: Seoyeon/Seoyeon50.mp3 to s3://neelmiranitest2/Seoyeon50.mp3
# move: Seoyeon/Seoyeon28.mp3 to s3://neelmiranitest2/Seoyeon28.mp3
# move: Seoyeon/Seoyeon92.mp3 to s3://neelmiranitest2/Seoyeon92.mp3
# move: Seoyeon/Seoyeon11.mp3 to s3://neelmiranitest2/Seoyeon11.mp3
# move: Seoyeon/Seoyeon2.mp3 to s3://neelmiranitest2/Seoyeon2.mp3
# move: Seoyeon/Seoyeon37.mp3 to s3://neelmiranitest2/Seoyeon37.mp3
# move: Seoyeon/Seoyeon25.mp3 to s3://neelmiranitest2/Seoyeon25.mp3
# move: Seoyeon/Seoyeon10.mp3 to s3://neelmiranitest2/Seoyeon10.mp3
# move: Seoyeon/Seoyeon77.mp3 to s3://neelmiranitest2/Seoyeon77.mp3
# move: Seoyeon/Seoyeon43.mp3 to s3://neelmiranitest2/Seoyeon43.mp3
# move: Seoyeon/Seoyeon63.mp3 to s3://neelmiranitest2/Seoyeon63.mp3
# move: Seoyeon/Seoyeon98.mp3 to s3://neelmiranitest2/Seoyeon98.mp3
# move: Seoyeon/Seoyeon93.mp3 to s3://neelmiranitest2/Seoyeon93.mp3
# move: Seoyeon/Seoyeon76.mp3 to s3://neelmiranitest2/Seoyeon76.mp3
# move: Seoyeon/Seoyeon90.mp3 to s3://neelmiranitest2/Seoyeon90.mp3
# move: Seoyeon/Seoyeon34.mp3 to s3://neelmiranitest2/Seoyeon34.mp3
# move: Seoyeon/Seoyeon91.mp3 to s3://neelmiranitest2/Seoyeon91.mp3
# move: Seoyeon/Seoyeon80.mp3 to s3://neelmiranitest2/Seoyeon80.mp3
# move: Seoyeon/Seoyeon22.mp3 to s3://neelmiranitest2/Seoyeon22.mp3
# move: Seoyeon/Seoyeon3.mp3 to s3://neelmiranitest2/Seoyeon3.mp3
# move: Seoyeon/Seoyeon30.mp3 to s3://neelmiranitest2/Seoyeon30.mp3
# move: Seoyeon/Seoyeon66.mp3 to s3://neelmiranitest2/Seoyeon66.mp3
# move: Seoyeon/Seoyeon99.mp3 to s3://neelmiranitest2/Seoyeon99.mp3
# move: Seoyeon/Seoyeon15.mp3 to s3://neelmiranitest2/Seoyeon15.mp3
# move: Seoyeon/Seoyeon75.mp3 to s3://neelmiranitest2/Seoyeon75.mp3
# move: Seoyeon/Seoyeon55.mp3 to s3://neelmiranitest2/Seoyeon55.mp3
# move: Seoyeon/Seoyeon19.mp3 to s3://neelmiranitest2/Seoyeon19.mp3
# move: Seoyeon/Seoyeon89.mp3 to s3://neelmiranitest2/Seoyeon89.mp3
# move: Seoyeon/Seoyeon6.mp3 to s3://neelmiranitest2/Seoyeon6.mp3
# move: Seoyeon/Seoyeon35.mp3 to s3://neelmiranitest2/Seoyeon35.mp3
# move: Seoyeon/Seoyeon61.mp3 to s3://neelmiranitest2/Seoyeon61.mp3
# move: Seoyeon/Seoyeon8.mp3 to s3://neelmiranitest2/Seoyeon8.mp3
# move: Seoyeon/Seoyeon40.mp3 to s3://neelmiranitest2/Seoyeon40.mp3
# move: Seoyeon/Seoyeon81.mp3 to s3://neelmiranitest2/Seoyeon81.mp3
# move: Seoyeon/Seoyeon32.mp3 to s3://neelmiranitest2/Seoyeon32.mp3
# move: Seoyeon/Seoyeon82.mp3 to s3://neelmiranitest2/Seoyeon82.mp3
# move: Seoyeon/Seoyeon4.mp3 to s3://neelmiranitest2/Seoyeon4.mp3
# move: Seoyeon/Seoyeon65.mp3 to s3://neelmiranitest2/Seoyeon65.mp3
# move: Seoyeon/Seoyeon56.mp3 to s3://neelmiranitest2/Seoyeon56.mp3
# move: Seoyeon/Seoyeon74.mp3 to s3://neelmiranitest2/Seoyeon74.mp3
# move: Seoyeon/Seoyeon85.mp3 to s3://neelmiranitest2/Seoyeon85.mp3
# move: Seoyeon/Seoyeon21.mp3 to s3://neelmiranitest2/Seoyeon21.mp3
# move: Seoyeon/Seoyeon36.mp3 to s3://neelmiranitest2/Seoyeon36.mp3
# move: Seoyeon/Seoyeon12.mp3 to s3://neelmiranitest2/Seoyeon12.mp3
# move: Seoyeon/Seoyeon24.mp3 to s3://neelmiranitest2/Seoyeon24.mp3
# move: Seoyeon/Seoyeon16.mp3 to s3://neelmiranitest2/Seoyeon16.mp3
# move: Seoyeon/Seoyeon9.mp3 to s3://neelmiranitest2/Seoyeon9.mp3
# move: Seoyeon/Seoyeon64.mp3 to s3://neelmiranitest2/Seoyeon64.mp3
# move: Seoyeon/Seoyeon41.mp3 to s3://neelmiranitest2/Seoyeon41.mp3
# move: Seoyeon/Seoyeon86.mp3 to s3://neelmiranitest2/Seoyeon86.mp3
# move: Seoyeon/Seoyeon49.mp3 to s3://neelmiranitest2/Seoyeon49.mp3
# move: Seoyeon/Seoyeon87.mp3 to s3://neelmiranitest2/Seoyeon87.mp3
# move: Seoyeon/Seoyeon7.mp3 to s3://neelmiranitest2/Seoyeon7.mp3
# move: Seoyeon/Seoyeon83.mp3 to s3://neelmiranitest2/Seoyeon83.mp3
# move: Seoyeon/Seoyeon84.mp3 to s3://neelmiranitest2/Seoyeon84.mp3
# move: Seoyeon/Seoyeon96.mp3 to s3://neelmiranitest2/Seoyeon96.mp3
# move: Seoyeon/Seoyeon79.mp3 to s3://neelmiranitest2/Seoyeon79.mp3
# move: Seoyeon/Seoyeon54.mp3 to s3://neelmiranitest2/Seoyeon54.mp3
# move: Seoyeon/Seoyeon62.mp3 to s3://neelmiranitest2/Seoyeon62.mp3
# move: Seoyeon/Seoyeon27.mp3 to s3://neelmiranitest2/Seoyeon27.mp3
# move: Seoyeon/Seoyeon18.mp3 to s3://neelmiranitest2/Seoyeon18.mp3
# move: Seoyeon/Seoyeon73.mp3 to s3://neelmiranitest2/Seoyeon73.mp3
# move: Seoyeon/Seoyeon72.mp3 to s3://neelmiranitest2/Seoyeon72.mp3
# move: Seoyeon/Seoyeon46.mp3 to s3://neelmiranitest2/Seoyeon46.mp3
# move: Seoyeon/Seoyeon53.mp3 to s3://neelmiranitest2/Seoyeon53.mp3
# move: Seoyeon/Seoyeon47.mp3 to s3://neelmiranitest2/Seoyeon47.mp3
# move: Seoyeon/Seoyeon5.mp3 to s3://neelmiranitest2/Seoyeon5.mp3
# move: Seoyeon/Seoyeon57.mp3 to s3://neelmiranitest2/Seoyeon57.mp3
# move: Seoyeon/Seoyeon68.mp3 to s3://neelmiranitest2/Seoyeon68.mp3
# move: Seoyeon/Seoyeon69.mp3 to s3://neelmiranitest2/Seoyeon69.mp3
# move: Seoyeon/Seoyeon26.mp3 to s3://neelmiranitest2/Seoyeon26.mp3
# move: Seoyeon/Seoyeon29.mp3 to s3://neelmiranitest2/Seoyeon29.mp3
# move: Seoyeon/Seoyeon45.mp3 to s3://neelmiranitest2/Seoyeon45.mp3
# move: Seoyeon/Seoyeon14.mp3 to s3://neelmiranitest2/Seoyeon14.mp3
# move: Seoyeon/Seoyeon44.mp3 to s3://neelmiranitest2/Seoyeon44.mp3
# move: Seoyeon/Seoyeon71.mp3 to s3://neelmiranitest2/Seoyeon71.mp3
# move: Seoyeon/Seoyeon42.mp3 to s3://neelmiranitest2/Seoyeon42.mp3
# move: Seoyeon/Seoyeon13.mp3 to s3://neelmiranitest2/Seoyeon13.mp3
# move: Seoyeon/Seoyeon33.mp3 to s3://neelmiranitest2/Seoyeon33.mp3
# move: Seoyeon/Seoyeon17.mp3 to s3://neelmiranitest2/Seoyeon17.mp3
# move: Seoyeon/Seoyeon1.mp3 to s3://neelmiranitest2/Seoyeon1.mp3
# move: Seoyeon/Seoyeon67.mp3 to s3://neelmiranitest2/Seoyeon67.mp3
# move: Seoyeon/Seoyeon97.mp3 to s3://neelmiranitest2/Seoyeon97.mp3
# move: Seoyeon/Seoyeon52.mp3 to s3://neelmiranitest2/Seoyeon52.mp3
# move: Seoyeon/Seoyeon78.mp3 to s3://neelmiranitest2/Seoyeon78.mp3
# move: Seoyeon/Seoyeon58.mp3 to s3://neelmiranitest2/Seoyeon58.mp3
# move: Seoyeon/Seoyeon88.mp3 to s3://neelmiranitest2/Seoyeon88.mp3
# move: Seoyeon/Seoyeon95.mp3 to s3://neelmiranitest2/Seoyeon95.mp3
# move: Seoyeon/Seoyeon60.mp3 to s3://neelmiranitest2/Seoyeon60.mp3
# move: Seoyeon/Seoyeon23.mp3 to s3://neelmiranitest2/Seoyeon23.mp3
# move: Seoyeon/Seoyeon59.mp3 to s3://neelmiranitest2/Seoyeon59.mp3
# move: Seoyeon/Seoyeon20.mp3 to s3://neelmiranitest2/Seoyeon20.mp3
# move: Seoyeon/Seoyeon48.mp3 to s3://neelmiranitest2/Seoyeon48.mp3
# move: Lea/Lea50.mp3 to s3://neelmiranitest2/Lea50.mp3
# move: Lea/Lea6.mp3 to s3://neelmiranitest2/Lea6.mp3
# move: Lea/Lea56.mp3 to s3://neelmiranitest2/Lea56.mp3
# move: Lea/Lea4.mp3 to s3://neelmiranitest2/Lea4.mp3
# move: Lea/Lea96.mp3 to s3://neelmiranitest2/Lea96.mp3
# move: Lea/Lea2.mp3 to s3://neelmiranitest2/Lea2.mp3
# move: Lea/Lea97.mp3 to s3://neelmiranitest2/Lea97.mp3
# move: Lea/Lea17.mp3 to s3://neelmiranitest2/Lea17.mp3
# move: Lea/Lea52.mp3 to s3://neelmiranitest2/Lea52.mp3
# move: Lea/Lea76.mp3 to s3://neelmiranitest2/Lea76.mp3
# move: Lea/Lea25.mp3 to s3://neelmiranitest2/Lea25.mp3
# move: Lea/Lea37.mp3 to s3://neelmiranitest2/Lea37.mp3
# move: Lea/Lea59.mp3 to s3://neelmiranitest2/Lea59.mp3
# move: Lea/Lea29.mp3 to s3://neelmiranitest2/Lea29.mp3
# move: Lea/Lea26.mp3 to s3://neelmiranitest2/Lea26.mp3
# move: Lea/Lea57.mp3 to s3://neelmiranitest2/Lea57.mp3
# move: Lea/Lea54.mp3 to s3://neelmiranitest2/Lea54.mp3
# move: Lea/Lea47.mp3 to s3://neelmiranitest2/Lea47.mp3
# move: Lea/Lea70.mp3 to s3://neelmiranitest2/Lea70.mp3
# move: Lea/Lea65.mp3 to s3://neelmiranitest2/Lea65.mp3
# move: Lea/Lea38.mp3 to s3://neelmiranitest2/Lea38.mp3
# move: Lea/Lea84.mp3 to s3://neelmiranitest2/Lea84.mp3
# move: Lea/Lea21.mp3 to s3://neelmiranitest2/Lea21.mp3
# move: Lea/Lea60.mp3 to s3://neelmiranitest2/Lea60.mp3
# move: Lea/Lea72.mp3 to s3://neelmiranitest2/Lea72.mp3
# move: Lea/Lea92.mp3 to s3://neelmiranitest2/Lea92.mp3
# move: Lea/Lea23.mp3 to s3://neelmiranitest2/Lea23.mp3
# move: Lea/Lea58.mp3 to s3://neelmiranitest2/Lea58.mp3
# move: Lea/Lea3.mp3 to s3://neelmiranitest2/Lea3.mp3
# move: Lea/Lea48.mp3 to s3://neelmiranitest2/Lea48.mp3
# move: Lea/Lea45.mp3 to s3://neelmiranitest2/Lea45.mp3
# move: Lea/Lea75.mp3 to s3://neelmiranitest2/Lea75.mp3
# move: Lea/Lea36.mp3 to s3://neelmiranitest2/Lea36.mp3
# move: Lea/Lea41.mp3 to s3://neelmiranitest2/Lea41.mp3
# move: Lea/Lea87.mp3 to s3://neelmiranitest2/Lea87.mp3
# move: Lea/Lea100.mp3 to s3://neelmiranitest2/Lea100.mp3
# move: Lea/Lea79.mp3 to s3://neelmiranitest2/Lea79.mp3
# move: Lea/Lea77.mp3 to s3://neelmiranitest2/Lea77.mp3
# move: Lea/Lea20.mp3 to s3://neelmiranitest2/Lea20.mp3
# move: Lea/Lea64.mp3 to s3://neelmiranitest2/Lea64.mp3
# move: Lea/Lea10.mp3 to s3://neelmiranitest2/Lea10.mp3
# move: Lea/Lea61.mp3 to s3://neelmiranitest2/Lea61.mp3
# move: Lea/Lea91.mp3 to s3://neelmiranitest2/Lea91.mp3
# move: Lea/Lea95.mp3 to s3://neelmiranitest2/Lea95.mp3
# move: Lea/Lea34.mp3 to s3://neelmiranitest2/Lea34.mp3
# move: Lea/Lea98.mp3 to s3://neelmiranitest2/Lea98.mp3
# move: Lea/Lea30.mp3 to s3://neelmiranitest2/Lea30.mp3
# move: Lea/Lea67.mp3 to s3://neelmiranitest2/Lea67.mp3
# move: Lea/Lea33.mp3 to s3://neelmiranitest2/Lea33.mp3
# move: Lea/Lea35.mp3 to s3://neelmiranitest2/Lea35.mp3
# move: Lea/Lea99.mp3 to s3://neelmiranitest2/Lea99.mp3
# move: Lea/Lea71.mp3 to s3://neelmiranitest2/Lea71.mp3
# move: Lea/Lea40.mp3 to s3://neelmiranitest2/Lea40.mp3
# move: Lea/Lea49.mp3 to s3://neelmiranitest2/Lea49.mp3
# move: Lea/Lea80.mp3 to s3://neelmiranitest2/Lea80.mp3
# move: Lea/Lea1.mp3 to s3://neelmiranitest2/Lea1.mp3
# move: Lea/Lea51.mp3 to s3://neelmiranitest2/Lea51.mp3
# move: Lea/Lea7.mp3 to s3://neelmiranitest2/Lea7.mp3
# move: Lea/Lea89.mp3 to s3://neelmiranitest2/Lea89.mp3
# move: Lea/Lea39.mp3 to s3://neelmiranitest2/Lea39.mp3
# move: Lea/Lea62.mp3 to s3://neelmiranitest2/Lea62.mp3
# move: Lea/Lea27.mp3 to s3://neelmiranitest2/Lea27.mp3
# move: Lea/Lea9.mp3 to s3://neelmiranitest2/Lea9.mp3
# move: Lea/Lea53.mp3 to s3://neelmiranitest2/Lea53.mp3
# move: Lea/Lea94.mp3 to s3://neelmiranitest2/Lea94.mp3
# move: Lea/Lea86.mp3 to s3://neelmiranitest2/Lea86.mp3
# move: Lea/Lea81.mp3 to s3://neelmiranitest2/Lea81.mp3
# move: Lea/Lea24.mp3 to s3://neelmiranitest2/Lea24.mp3
# move: Lea/Lea88.mp3 to s3://neelmiranitest2/Lea88.mp3
# move: Lea/Lea55.mp3 to s3://neelmiranitest2/Lea55.mp3
# move: Lea/Lea83.mp3 to s3://neelmiranitest2/Lea83.mp3
# move: Lea/Lea18.mp3 to s3://neelmiranitest2/Lea18.mp3
# move: Lea/Lea73.mp3 to s3://neelmiranitest2/Lea73.mp3
# move: Lea/Lea28.mp3 to s3://neelmiranitest2/Lea28.mp3
# move: Lea/Lea16.mp3 to s3://neelmiranitest2/Lea16.mp3
# move: Lea/Lea5.mp3 to s3://neelmiranitest2/Lea5.mp3
# move: Lea/Lea93.mp3 to s3://neelmiranitest2/Lea93.mp3
# move: Lea/Lea66.mp3 to s3://neelmiranitest2/Lea66.mp3
# move: Lea/Lea46.mp3 to s3://neelmiranitest2/Lea46.mp3
# move: Lea/Lea32.mp3 to s3://neelmiranitest2/Lea32.mp3
# move: Lea/Lea19.mp3 to s3://neelmiranitest2/Lea19.mp3
# move: Lea/Lea31.mp3 to s3://neelmiranitest2/Lea31.mp3
# move: Lea/Lea82.mp3 to s3://neelmiranitest2/Lea82.mp3
# move: Lea/Lea14.mp3 to s3://neelmiranitest2/Lea14.mp3
# move: Lea/Lea69.mp3 to s3://neelmiranitest2/Lea69.mp3
# move: Lea/Lea8.mp3 to s3://neelmiranitest2/Lea8.mp3
# move: Lea/Lea11.mp3 to s3://neelmiranitest2/Lea11.mp3
# move: Lea/Lea63.mp3 to s3://neelmiranitest2/Lea63.mp3
# move: Lea/Lea42.mp3 to s3://neelmiranitest2/Lea42.mp3
# move: Lea/Lea68.mp3 to s3://neelmiranitest2/Lea68.mp3
# move: Lea/Lea44.mp3 to s3://neelmiranitest2/Lea44.mp3
# move: Lea/Lea12.mp3 to s3://neelmiranitest2/Lea12.mp3
# move: Lea/Lea22.mp3 to s3://neelmiranitest2/Lea22.mp3
# move: Lea/Lea13.mp3 to s3://neelmiranitest2/Lea13.mp3
# move: Lea/Lea15.mp3 to s3://neelmiranitest2/Lea15.mp3
# move: Lea/Lea90.mp3 to s3://neelmiranitest2/Lea90.mp3
# move: Lea/Lea78.mp3 to s3://neelmiranitest2/Lea78.mp3
# move: Lea/Lea74.mp3 to s3://neelmiranitest2/Lea74.mp3
# move: Lea/Lea43.mp3 to s3://neelmiranitest2/Lea43.mp3
# move: Lea/Lea85.mp3 to s3://neelmiranitest2/Lea85.mp3
# move: Lucia/Lucia92.mp3 to s3://neelmiranitest2/Lucia92.mp3
# move: Lucia/Lucia26.mp3 to s3://neelmiranitest2/Lucia26.mp3
# move: Lucia/Lucia30.mp3 to s3://neelmiranitest2/Lucia30.mp3
# move: Lucia/Lucia38.mp3 to s3://neelmiranitest2/Lucia38.mp3
# move: Lucia/Lucia84.mp3 to s3://neelmiranitest2/Lucia84.mp3
# move: Lucia/Lucia57.mp3 to s3://neelmiranitest2/Lucia57.mp3
# move: Lucia/Lucia44.mp3 to s3://neelmiranitest2/Lucia44.mp3
# move: Lucia/Lucia53.mp3 to s3://neelmiranitest2/Lucia53.mp3
# move: Lucia/Lucia88.mp3 to s3://neelmiranitest2/Lucia88.mp3
# move: Lucia/Lucia59.mp3 to s3://neelmiranitest2/Lucia59.mp3
# move: Lucia/Lucia40.mp3 to s3://neelmiranitest2/Lucia40.mp3
# move: Lucia/Lucia62.mp3 to s3://neelmiranitest2/Lucia62.mp3
# move: Lucia/Lucia23.mp3 to s3://neelmiranitest2/Lucia23.mp3
# move: Lucia/Lucia73.mp3 to s3://neelmiranitest2/Lucia73.mp3
# move: Lucia/Lucia37.mp3 to s3://neelmiranitest2/Lucia37.mp3
# move: Lucia/Lucia14.mp3 to s3://neelmiranitest2/Lucia14.mp3
# move: Lucia/Lucia33.mp3 to s3://neelmiranitest2/Lucia33.mp3
# move: Lucia/Lucia91.mp3 to s3://neelmiranitest2/Lucia91.mp3
# move: Lucia/Lucia48.mp3 to s3://neelmiranitest2/Lucia48.mp3
# move: Lucia/Lucia93.mp3 to s3://neelmiranitest2/Lucia93.mp3
# move: Lucia/Lucia42.mp3 to s3://neelmiranitest2/Lucia42.mp3
# move: Lucia/Lucia46.mp3 to s3://neelmiranitest2/Lucia46.mp3
# move: Lucia/Lucia25.mp3 to s3://neelmiranitest2/Lucia25.mp3
# move: Lucia/Lucia87.mp3 to s3://neelmiranitest2/Lucia87.mp3
# move: Lucia/Lucia51.mp3 to s3://neelmiranitest2/Lucia51.mp3
# move: Lucia/Lucia10.mp3 to s3://neelmiranitest2/Lucia10.mp3
# move: Lucia/Lucia47.mp3 to s3://neelmiranitest2/Lucia47.mp3
# move: Lucia/Lucia28.mp3 to s3://neelmiranitest2/Lucia28.mp3
# move: Lucia/Lucia98.mp3 to s3://neelmiranitest2/Lucia98.mp3
# move: Lucia/Lucia86.mp3 to s3://neelmiranitest2/Lucia86.mp3
# move: Lucia/Lucia77.mp3 to s3://neelmiranitest2/Lucia77.mp3
# move: Lucia/Lucia8.mp3 to s3://neelmiranitest2/Lucia8.mp3
# move: Lucia/Lucia68.mp3 to s3://neelmiranitest2/Lucia68.mp3
# move: Lucia/Lucia83.mp3 to s3://neelmiranitest2/Lucia83.mp3
# move: Lucia/Lucia50.mp3 to s3://neelmiranitest2/Lucia50.mp3
# move: Lucia/Lucia79.mp3 to s3://neelmiranitest2/Lucia79.mp3
# move: Lucia/Lucia12.mp3 to s3://neelmiranitest2/Lucia12.mp3
# move: Lucia/Lucia41.mp3 to s3://neelmiranitest2/Lucia41.mp3
# move: Lucia/Lucia89.mp3 to s3://neelmiranitest2/Lucia89.mp3
# move: Lucia/Lucia17.mp3 to s3://neelmiranitest2/Lucia17.mp3
# move: Lucia/Lucia21.mp3 to s3://neelmiranitest2/Lucia21.mp3
# move: Lucia/Lucia16.mp3 to s3://neelmiranitest2/Lucia16.mp3
# move: Lucia/Lucia27.mp3 to s3://neelmiranitest2/Lucia27.mp3
# move: Lucia/Lucia9.mp3 to s3://neelmiranitest2/Lucia9.mp3
# move: Lucia/Lucia64.mp3 to s3://neelmiranitest2/Lucia64.mp3
# move: Lucia/Lucia63.mp3 to s3://neelmiranitest2/Lucia63.mp3
# move: Lucia/Lucia7.mp3 to s3://neelmiranitest2/Lucia7.mp3
# move: Lucia/Lucia82.mp3 to s3://neelmiranitest2/Lucia82.mp3
# move: Lucia/Lucia65.mp3 to s3://neelmiranitest2/Lucia65.mp3
# move: Lucia/Lucia99.mp3 to s3://neelmiranitest2/Lucia99.mp3
# move: Lucia/Lucia96.mp3 to s3://neelmiranitest2/Lucia96.mp3
# move: Lucia/Lucia70.mp3 to s3://neelmiranitest2/Lucia70.mp3
# move: Lucia/Lucia76.mp3 to s3://neelmiranitest2/Lucia76.mp3
# move: Lucia/Lucia56.mp3 to s3://neelmiranitest2/Lucia56.mp3
# move: Lucia/Lucia1.mp3 to s3://neelmiranitest2/Lucia1.mp3
# move: Lucia/Lucia22.mp3 to s3://neelmiranitest2/Lucia22.mp3
# move: Lucia/Lucia61.mp3 to s3://neelmiranitest2/Lucia61.mp3
# move: Lucia/Lucia74.mp3 to s3://neelmiranitest2/Lucia74.mp3
# move: Lucia/Lucia67.mp3 to s3://neelmiranitest2/Lucia67.mp3
# move: Lucia/Lucia43.mp3 to s3://neelmiranitest2/Lucia43.mp3
# move: Lucia/Lucia45.mp3 to s3://neelmiranitest2/Lucia45.mp3
# move: Lucia/Lucia94.mp3 to s3://neelmiranitest2/Lucia94.mp3
# move: Lucia/Lucia13.mp3 to s3://neelmiranitest2/Lucia13.mp3
# move: Lucia/Lucia11.mp3 to s3://neelmiranitest2/Lucia11.mp3
# move: Lucia/Lucia35.mp3 to s3://neelmiranitest2/Lucia35.mp3
# move: Lucia/Lucia85.mp3 to s3://neelmiranitest2/Lucia85.mp3
# move: Lucia/Lucia54.mp3 to s3://neelmiranitest2/Lucia54.mp3
# move: Lucia/Lucia60.mp3 to s3://neelmiranitest2/Lucia60.mp3
# move: Lucia/Lucia19.mp3 to s3://neelmiranitest2/Lucia19.mp3
# move: Lucia/Lucia2.mp3 to s3://neelmiranitest2/Lucia2.mp3
# move: Lucia/Lucia18.mp3 to s3://neelmiranitest2/Lucia18.mp3
# move: Lucia/Lucia80.mp3 to s3://neelmiranitest2/Lucia80.mp3
# move: Lucia/Lucia4.mp3 to s3://neelmiranitest2/Lucia4.mp3
# move: Lucia/Lucia69.mp3 to s3://neelmiranitest2/Lucia69.mp3
# move: Lucia/Lucia72.mp3 to s3://neelmiranitest2/Lucia72.mp3
# move: Lucia/Lucia6.mp3 to s3://neelmiranitest2/Lucia6.mp3
# move: Lucia/Lucia29.mp3 to s3://neelmiranitest2/Lucia29.mp3
# move: Lucia/Lucia36.mp3 to s3://neelmiranitest2/Lucia36.mp3
# move: Lucia/Lucia24.mp3 to s3://neelmiranitest2/Lucia24.mp3
# move: Lucia/Lucia39.mp3 to s3://neelmiranitest2/Lucia39.mp3
# move: Lucia/Lucia5.mp3 to s3://neelmiranitest2/Lucia5.mp3
# move: Lucia/Lucia55.mp3 to s3://neelmiranitest2/Lucia55.mp3
# move: Lucia/Lucia52.mp3 to s3://neelmiranitest2/Lucia52.mp3
# move: Lucia/Lucia58.mp3 to s3://neelmiranitest2/Lucia58.mp3
# move: Lucia/Lucia81.mp3 to s3://neelmiranitest2/Lucia81.mp3
# move: Lucia/Lucia34.mp3 to s3://neelmiranitest2/Lucia34.mp3
# move: Lucia/Lucia66.mp3 to s3://neelmiranitest2/Lucia66.mp3
# move: Lucia/Lucia3.mp3 to s3://neelmiranitest2/Lucia3.mp3
# move: Lucia/Lucia31.mp3 to s3://neelmiranitest2/Lucia31.mp3
# move: Lucia/Lucia97.mp3 to s3://neelmiranitest2/Lucia97.mp3
# move: Lucia/Lucia100.mp3 to s3://neelmiranitest2/Lucia100.mp3
# move: Lucia/Lucia49.mp3 to s3://neelmiranitest2/Lucia49.mp3
# move: Lucia/Lucia95.mp3 to s3://neelmiranitest2/Lucia95.mp3
# move: Lucia/Lucia71.mp3 to s3://neelmiranitest2/Lucia71.mp3
# move: Lucia/Lucia15.mp3 to s3://neelmiranitest2/Lucia15.mp3
# move: Lucia/Lucia20.mp3 to s3://neelmiranitest2/Lucia20.mp3
# move: Lucia/Lucia90.mp3 to s3://neelmiranitest2/Lucia90.mp3
# move: Lucia/Lucia78.mp3 to s3://neelmiranitest2/Lucia78.mp3
# move: Lucia/Lucia32.mp3 to s3://neelmiranitest2/Lucia32.mp3
# move: Lucia/Lucia75.mp3 to s3://neelmiranitest2/Lucia75.mp3
# move: Aditi/Aditi78.mp3 to s3://neelmiranitest2/Aditi78.mp3
# move: Aditi/Aditi70.mp3 to s3://neelmiranitest2/Aditi70.mp3
# move: Aditi/Aditi42.mp3 to s3://neelmiranitest2/Aditi42.mp3
# move: Aditi/Aditi7.mp3 to s3://neelmiranitest2/Aditi7.mp3
# move: Aditi/Aditi9.mp3 to s3://neelmiranitest2/Aditi9.mp3
# move: Aditi/Aditi38.mp3 to s3://neelmiranitest2/Aditi38.mp3
# move: Aditi/Aditi62.mp3 to s3://neelmiranitest2/Aditi62.mp3
# move: Aditi/Aditi73.mp3 to s3://neelmiranitest2/Aditi73.mp3
# move: Aditi/Aditi1.mp3 to s3://neelmiranitest2/Aditi1.mp3
# move: Aditi/Aditi87.mp3 to s3://neelmiranitest2/Aditi87.mp3
# move: Aditi/Aditi23.mp3 to s3://neelmiranitest2/Aditi23.mp3
# move: Aditi/Aditi100.mp3 to s3://neelmiranitest2/Aditi100.mp3
# move: Aditi/Aditi16.mp3 to s3://neelmiranitest2/Aditi16.mp3
# move: Aditi/Aditi26.mp3 to s3://neelmiranitest2/Aditi26.mp3
# move: Aditi/Aditi95.mp3 to s3://neelmiranitest2/Aditi95.mp3
# move: Aditi/Aditi68.mp3 to s3://neelmiranitest2/Aditi68.mp3
# move: Aditi/Aditi31.mp3 to s3://neelmiranitest2/Aditi31.mp3
# move: Aditi/Aditi90.mp3 to s3://neelmiranitest2/Aditi90.mp3
# move: Aditi/Aditi56.mp3 to s3://neelmiranitest2/Aditi56.mp3
# move: Aditi/Aditi74.mp3 to s3://neelmiranitest2/Aditi74.mp3
# move: Aditi/Aditi17.mp3 to s3://neelmiranitest2/Aditi17.mp3
# move: Aditi/Aditi80.mp3 to s3://neelmiranitest2/Aditi80.mp3
# move: Aditi/Aditi97.mp3 to s3://neelmiranitest2/Aditi97.mp3
# move: Aditi/Aditi30.mp3 to s3://neelmiranitest2/Aditi30.mp3
# move: Aditi/Aditi72.mp3 to s3://neelmiranitest2/Aditi72.mp3
# move: Aditi/Aditi83.mp3 to s3://neelmiranitest2/Aditi83.mp3
# move: Aditi/Aditi64.mp3 to s3://neelmiranitest2/Aditi64.mp3
# move: Aditi/Aditi27.mp3 to s3://neelmiranitest2/Aditi27.mp3
# move: Aditi/Aditi8.mp3 to s3://neelmiranitest2/Aditi8.mp3
# move: Aditi/Aditi69.mp3 to s3://neelmiranitest2/Aditi69.mp3
# move: Aditi/Aditi52.mp3 to s3://neelmiranitest2/Aditi52.mp3
# move: Aditi/Aditi76.mp3 to s3://neelmiranitest2/Aditi76.mp3
# move: Aditi/Aditi49.mp3 to s3://neelmiranitest2/Aditi49.mp3
# move: Aditi/Aditi77.mp3 to s3://neelmiranitest2/Aditi77.mp3
# move: Aditi/Aditi63.mp3 to s3://neelmiranitest2/Aditi63.mp3
# move: Aditi/Aditi75.mp3 to s3://neelmiranitest2/Aditi75.mp3
# move: Aditi/Aditi91.mp3 to s3://neelmiranitest2/Aditi91.mp3
# move: Aditi/Aditi25.mp3 to s3://neelmiranitest2/Aditi25.mp3
# move: Aditi/Aditi53.mp3 to s3://neelmiranitest2/Aditi53.mp3
# move: Aditi/Aditi12.mp3 to s3://neelmiranitest2/Aditi12.mp3
# move: Aditi/Aditi33.mp3 to s3://neelmiranitest2/Aditi33.mp3
# move: Aditi/Aditi18.mp3 to s3://neelmiranitest2/Aditi18.mp3
# move: Aditi/Aditi65.mp3 to s3://neelmiranitest2/Aditi65.mp3
# move: Aditi/Aditi96.mp3 to s3://neelmiranitest2/Aditi96.mp3
# move: Aditi/Aditi67.mp3 to s3://neelmiranitest2/Aditi67.mp3
# move: Aditi/Aditi47.mp3 to s3://neelmiranitest2/Aditi47.mp3
# move: Aditi/Aditi84.mp3 to s3://neelmiranitest2/Aditi84.mp3
# move: Aditi/Aditi19.mp3 to s3://neelmiranitest2/Aditi19.mp3
# move: Aditi/Aditi37.mp3 to s3://neelmiranitest2/Aditi37.mp3
# move: Aditi/Aditi4.mp3 to s3://neelmiranitest2/Aditi4.mp3
# move: Aditi/Aditi93.mp3 to s3://neelmiranitest2/Aditi93.mp3
# move: Aditi/Aditi41.mp3 to s3://neelmiranitest2/Aditi41.mp3
# move: Aditi/Aditi60.mp3 to s3://neelmiranitest2/Aditi60.mp3
# move: Aditi/Aditi45.mp3 to s3://neelmiranitest2/Aditi45.mp3
# move: Aditi/Aditi79.mp3 to s3://neelmiranitest2/Aditi79.mp3
# move: Aditi/Aditi86.mp3 to s3://neelmiranitest2/Aditi86.mp3
# move: Aditi/Aditi99.mp3 to s3://neelmiranitest2/Aditi99.mp3
# move: Aditi/Aditi22.mp3 to s3://neelmiranitest2/Aditi22.mp3
# move: Aditi/Aditi61.mp3 to s3://neelmiranitest2/Aditi61.mp3
# move: Aditi/Aditi94.mp3 to s3://neelmiranitest2/Aditi94.mp3
# move: Aditi/Aditi82.mp3 to s3://neelmiranitest2/Aditi82.mp3
# move: Aditi/Aditi2.mp3 to s3://neelmiranitest2/Aditi2.mp3
# move: Aditi/Aditi34.mp3 to s3://neelmiranitest2/Aditi34.mp3
# move: Aditi/Aditi98.mp3 to s3://neelmiranitest2/Aditi98.mp3
# move: Aditi/Aditi46.mp3 to s3://neelmiranitest2/Aditi46.mp3
# move: Aditi/Aditi40.mp3 to s3://neelmiranitest2/Aditi40.mp3
# move: Aditi/Aditi21.mp3 to s3://neelmiranitest2/Aditi21.mp3
# move: Aditi/Aditi32.mp3 to s3://neelmiranitest2/Aditi32.mp3
# move: Aditi/Aditi28.mp3 to s3://neelmiranitest2/Aditi28.mp3
# move: Aditi/Aditi51.mp3 to s3://neelmiranitest2/Aditi51.mp3
# move: Aditi/Aditi89.mp3 to s3://neelmiranitest2/Aditi89.mp3
# move: Aditi/Aditi36.mp3 to s3://neelmiranitest2/Aditi36.mp3
# move: Aditi/Aditi58.mp3 to s3://neelmiranitest2/Aditi58.mp3
# move: Aditi/Aditi35.mp3 to s3://neelmiranitest2/Aditi35.mp3
# move: Aditi/Aditi59.mp3 to s3://neelmiranitest2/Aditi59.mp3
# move: Aditi/Aditi11.mp3 to s3://neelmiranitest2/Aditi11.mp3
# move: Aditi/Aditi24.mp3 to s3://neelmiranitest2/Aditi24.mp3
# move: Aditi/Aditi66.mp3 to s3://neelmiranitest2/Aditi66.mp3
# move: Aditi/Aditi15.mp3 to s3://neelmiranitest2/Aditi15.mp3
# move: Aditi/Aditi39.mp3 to s3://neelmiranitest2/Aditi39.mp3
# move: Aditi/Aditi88.mp3 to s3://neelmiranitest2/Aditi88.mp3
# move: Aditi/Aditi92.mp3 to s3://neelmiranitest2/Aditi92.mp3
# move: Aditi/Aditi48.mp3 to s3://neelmiranitest2/Aditi48.mp3
# move: Aditi/Aditi54.mp3 to s3://neelmiranitest2/Aditi54.mp3
# move: Aditi/Aditi43.mp3 to s3://neelmiranitest2/Aditi43.mp3
# move: Aditi/Aditi3.mp3 to s3://neelmiranitest2/Aditi3.mp3
# move: Aditi/Aditi20.mp3 to s3://neelmiranitest2/Aditi20.mp3
# move: Aditi/Aditi81.mp3 to s3://neelmiranitest2/Aditi81.mp3
# move: Aditi/Aditi14.mp3 to s3://neelmiranitest2/Aditi14.mp3
# move: Aditi/Aditi55.mp3 to s3://neelmiranitest2/Aditi55.mp3
# move: Aditi/Aditi85.mp3 to s3://neelmiranitest2/Aditi85.mp3
# move: Aditi/Aditi57.mp3 to s3://neelmiranitest2/Aditi57.mp3
# move: Aditi/Aditi50.mp3 to s3://neelmiranitest2/Aditi50.mp3
# move: Aditi/Aditi29.mp3 to s3://neelmiranitest2/Aditi29.mp3
# move: Aditi/Aditi13.mp3 to s3://neelmiranitest2/Aditi13.mp3
# move: Aditi/Aditi71.mp3 to s3://neelmiranitest2/Aditi71.mp3
# move: Aditi/Aditi5.mp3 to s3://neelmiranitest2/Aditi5.mp3
